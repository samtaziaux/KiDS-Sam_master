# %%
#!/usr/bin/python

import numpy as np
import pyfits
import os

from matplotlib import pyplot as plt
# %matplotlib inline

envnames = ['Void', 'Sheet', 'Filament', 'Knot']
esdnames = ['esd_total', 'esd_central', 'esd_sat', 'esd_host']
esds = np.array([['%s%i'%(esd, i+1) for i in xrange(len(envnames))] for esd in esdnames])

print esds

filename = 'mcmc_output'
burn = 500
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-63-8402700b2218> in <module>()
#       4 import pyfits
#       5 import os
# ----> 6 import rc
#       7 from matplotlib import pyplot as plt
#       8 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named rc

# %%
# Importing mcmc results
def import_mcmc(filename):

    mcmcname = '%s.fits'%filename
    headername = '%s.hdr'%filename
    
    print 'Importing MCMC results:', mcmcname, 'and', headername
    mcmc = pyfits.open(mcmcname)[1].data
    
    mcmcmask = (mcmc['Msat1'] != 0)
    end = np.sum(mcmcmask)
    
    return mcmc, end, mcmcname, headername

# %%
def read_header(headername):
    header = open(headername, 'r').read().split('\n')
    header = np.array([header[i].split(' ') for i in xrange(len(header))])
    
    for line in header:
        if line[0] == 'datafile':
            esdfiles = line[1].split(',')
        elif line[0] == 'covfile':
            covfile = line[1]
        
    return esdfiles, covfile

# %%
def read_esdfiles(esdfiles):
    
    data = np.loadtxt(esdfiles[0]).T
    data_x = data[0]

    data_y = np.zeros(len(data_x))
    error_h = np.zeros(len(data_x))
    error_l = np.zeros(len(data_x))
    
    print 'Imported ESD profiles: %i'%len(esdfiles)
    
    for f in xrange(len(esdfiles)):
        # Load the text file containing the stacked profile
        data = np.loadtxt(esdfiles[f]).T
    
        bias = data[4]
        bias[bias==-999] = 1
    
        datax = data[0]
        datay = data[1]/bias
        datay[datay==-999] = np.nan
    
        errorh = (data[3])/bias # covariance error
        errorl = (data[3])/bias # covariance error
        errorh[errorh==-999] = np.nan
        errorl[errorl==-999] = np.nan
        
        
        data_y = np.vstack([data_y, datay])
        error_h = np.vstack([error_h, errorh])
        error_l = np.vstack([error_l, errorl])
        
    data_y = np.delete(data_y, 0, 0)
    error_h = np.delete(error_h, 0, 0)
    error_l = np.delete(error_l, 0, 0)
    
    return data_x, data_y, error_h, error_l

# %%
# Import MCMC results
mcmc, end, mcmcname, headername = import_mcmc(filename)
print 'Samples: Created = %i, Burned = %i, Used = %i'%(end, burn, end-burn)

# Import ESD profiles
esdfiles, covfile = read_header(headername)
data_x, data_y, error_h, error_l = read_esdfiles(esdfiles)
# Out:
# Importing MCMC results: mcmc_output.fits and mcmc_output.hdr
# Samples: Created = 1140, Burned = 500, Used = 640
# Imported ESD profiles: 4
# [[  1.61421228e+02   6.08655170e+01   4.21405648e+01   4.45682090e+01
#     2.33953120e+01   1.54878570e+01   1.13669904e+01   5.17876662e+00
#     3.96835702e+00   2.93209368e+00   2.03016798e+00   8.72941598e-01
#     3.01953320e-01   2.89241622e-01   2.30951322e-01   8.22573255e-02]
#  [  1.55536535e+02   1.14839536e+02   3.93731886e+01   4.42779852e+01
#     1.86982769e+01   1.01857700e+01   1.70454866e+01   7.04237829e+00
#     5.11206249e+00   4.29664065e+00   3.23693072e+00   1.54731786e+00
#     8.69768840e-01   6.58205368e-01   5.96139987e-01   7.42528010e-01]
#  [  4.94440983e+01   1.23853253e+02   4.81729327e+01   3.43615781e+01
#     2.45513316e+01   2.54986642e+01   1.49722682e+01   1.02316556e+01
#     8.44799072e+00   6.48695030e+00   6.20203953e+00   4.09928954e+00
#     1.85124060e+00   1.37112168e+00   1.10937830e+00   1.39853462e+00]
#  [  1.36973823e+02   1.64756993e+02   5.37084484e+01   9.97651929e+01
#     2.40252385e+01   2.75152665e+01   1.89295959e+01   4.53592474e+00
#     1.08746184e+01   9.08753221e+00   7.83554407e+00   7.75073483e+00
#     4.10503188e+00   4.68645863e+00   4.58736900e+00   2.95205869e+00]]
# [[  54.2418384    30.05360862   15.69187282    9.71679683    6.17512399
#      3.92271958    2.50718865    1.61384497    1.0511699     0.69392342
#      0.47313068    0.33755853    0.27323088    0.23541783    0.2282433
#      0.25067115]
#  [  64.85337033   34.64914703   17.12747522   10.52568294    6.64990172
#      4.22496414    2.70584258    1.74699042    1.15295528    0.78529143
#      0.54663655    0.39026601    0.30634222    0.24895689    0.23196527
#      0.23669483]
#  [  78.21959883   40.87891266   20.45015369   12.55981468    7.91554248
#      5.04260989    3.23653014    2.10257366    1.40021866    0.981283
#      0.73207571    0.57285796    0.4785943     0.41799512    0.38430165
#      0.37894747]
#  [ 176.95463234   94.61311073   44.60793135   27.00670487   17.06096176
#     10.80241285    6.9165297     4.49120603    2.98810641    2.08632603
#      1.57050492    1.28628497    1.2362782     1.16279819    1.03285922
#      0.97933213]]
# [[  54.2418384    30.05360862   15.69187282    9.71679683    6.17512399
#      3.92271958    2.50718865    1.61384497    1.0511699     0.69392342
#      0.47313068    0.33755853    0.27323088    0.23541783    0.2282433
#      0.25067115]
#  [  64.85337033   34.64914703   17.12747522   10.52568294    6.64990172
#      4.22496414    2.70584258    1.74699042    1.15295528    0.78529143
#      0.54663655    0.39026601    0.30634222    0.24895689    0.23196527
#      0.23669483]
#  [  78.21959883   40.87891266   20.45015369   12.55981468    7.91554248
#      5.04260989    3.23653014    2.10257366    1.40021866    0.981283
#      0.73207571    0.57285796    0.4785943     0.41799512    0.38430165
#      0.37894747]
#  [ 176.95463234   94.61311073   44.60793135   27.00670487   17.06096176
#     10.80241285    6.9165297     4.49120603    2.98810641    2.08632603
#      1.57050492    1.28628497    1.2362782     1.16279819    1.03285922
#      0.97933213]]

# %%
esds_av = np.array([[np.mean(mcmc[esds[e,0]][burn:end], 0) for e in xrange(len(esdnames))] for i in xrange(len(envnames))])

# %%
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import gridspec
from matplotlib import rc, rcParams

# Make use of TeX
rc('text',usetex=True)

# Change all fonts to 'Computer Modern'
rc('font',**{'family':'serif','serif':['Computer Modern']})



# Define the labels for the plot
h=0.1
xlabel = r'radius R [kpc/h$_{%g}$]'%(h*100)
ylabel = r'ESD $\langle\Delta\Sigma\rangle$ [h$_{%g}$ M$_{\odot}$/pc$^2$]'%(h*100)


for i in xrange(len(envnames)):
    for e in xrange(len(esdnames)):
        plt.figure(1, figsize=(10, 8))
        plt.plot(data_x, esds_av[i,e], label=esdnames[e])
    
        (error_l[e])[(error_l[e])>=data_y[e]] = ((data_y[e][(error_l[e])>=data_y[e]])*0.9999999999)
    
        plt.errorbar(data_x, data_y[i], yerr=[error_l[i], error_h[i]], ls='', marker='o')
        plt.ylabel(r'%s'%ylabel,fontsize=15)
        plt.xlabel(r'%s'%xlabel,fontsize=15)
        
    plt.autoscale(enable=False, axis='both', tight=None)
    plt.axis([1e1,1e4,1e-1,1e4])
    plt.ylim(1e-1,1e4)
    
        
    plt.legend()
    
    plt.xscale('log')
    plt.yscale('log')

    plt.show()
    plt.clf
