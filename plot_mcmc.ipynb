# %%
#!/usr/bin/python

import numpy as np
import pyfits
import os

from matplotlib import pyplot as plt
# %matplotlib inline

envnames = ['Void', 'Sheet', 'Filament', 'Knot']
esdnames = ['esd_total', 'esd_central', 'esd_sat', 'esd_host']
plotlabels = ['ESD_{tot}', 'ESD_{cen}', 'ESD_{sat}', 'ESD_{host}']
esds = np.array([['%s%i'%(esd, i+1) for i in xrange(len(envnames))] for esd in esdnames])

print esds

filename = '/disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output'
burn = 100000
# Out:
# [['esd_total1' 'esd_total2' 'esd_total3' 'esd_total4']
#  ['esd_central1' 'esd_central2' 'esd_central3' 'esd_central4']
#  ['esd_sat1' 'esd_sat2' 'esd_sat3' 'esd_sat4']
#  ['esd_host1' 'esd_host2' 'esd_host3' 'esd_host4']]

# %%
# Importing mcmc results
def import_mcmc(filename):

    mcmcname = '%s.fits'%filename
    headername = '%s.hdr'%filename
    
    print 'Importing MCMC results:', mcmcname
    print '                   and:', headername
    mcmc = pyfits.open(mcmcname)[1].data
    
    mcmcmask = (mcmc['Msat1'] != 0)
    end = np.sum(mcmcmask)
    
    return mcmc, end, mcmcname, headername

# %%
def read_header(headername):
    header = open(headername, 'r').read().split('\n')
    header = np.array([header[i].split(' ') for i in xrange(len(header))])
    
    for line in header:
        if line[0] == 'datafile':
            esdfiles = line[1].split(',')
        elif line[0] == 'covfile':
            covfile = line[1]
        
    return esdfiles, covfile

# %%
def read_esdfiles(esdfiles):
    
    data = np.loadtxt(esdfiles[0]).T
    data_x = data[0]

    data_y = np.zeros(len(data_x))
    error_h = np.zeros(len(data_x))
    error_l = np.zeros(len(data_x))
    
    print 'Imported ESD profiles: %i'%len(esdfiles)
    
    for f in xrange(len(esdfiles)):
        # Load the text file containing the stacked profile
        data = np.loadtxt(esdfiles[f]).T
    
        bias = data[4]
        bias[bias==-999] = 1
    
        datax = data[0]
        datay = data[1]/bias
        datay[datay==-999] = np.nan
    
        errorh = (data[3])/bias # covariance error
        errorl = (data[3])/bias # covariance error
        errorh[errorh==-999] = np.nan
        errorl[errorl==-999] = np.nan
        
        
        data_y = np.vstack([data_y, datay])
        error_h = np.vstack([error_h, errorh])
        error_l = np.vstack([error_l, errorl])
        
    data_y = np.delete(data_y, 0, 0)
    error_h = np.delete(error_h, 0, 0)
    error_l = np.delete(error_l, 0, 0)
    
    return data_x, data_y, error_h, error_l

# %%
# Import MCMC results
mcmc, end, mcmcname, headername = import_mcmc(filename)
print 'Samples: Created = %i, Burned = %i, Used = %i'%(end, burn, end-burn)

# Import ESD profiles
esdfiles, covfile = read_header(headername)
data_x, data_y, error_h, error_l = read_esdfiles(esdfiles)
# Out:
# Importing MCMC results: /disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output.fits
#                    and: /disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output.hdr
# Samples: Created = 140500, Burned = 100000, Used = 40500
# Imported ESD profiles: 4

# %%
esds_av = np.array([[np.mean(mcmc[esds[e,i]][burn:end], 0) for e in xrange(len(esdnames))] for i in xrange(len(envnames))])

print esds_av
# Out:
# [[[  4.28114853e+01   2.75089226e+01   1.90340176e+01   1.36310492e+01
#      9.83078766e+00   6.98428869e+00   4.77890301e+00   3.09105229e+00
#      1.87595737e+00   1.07006466e+00]
#   [  2.91562901e+01   1.66889210e+01   1.13696423e+01   8.70838642e+00
#      6.91878223e+00   5.36142683e+00   3.91168094e+00   2.64594865e+00
#      1.65588307e+00   9.64477897e-01]
#   [  1.02504478e+02   7.06943741e+01   4.69714012e+01   2.93617802e+01
#      1.71849842e+01   9.46554184e+00   4.95065165e+00   2.48207116e+00
#      1.20287716e+00   5.67394793e-01]
#   [  1.97811591e-17   4.11090851e+00   5.56751013e+00   5.78883600e+00
#      5.37536287e+00   4.61306095e+00   3.61943293e+00   2.55468869e+00
#      1.63513291e+00   9.64315414e-01]]
#
#  [[  5.41069756e+01   3.40044632e+01   2.31305656e+01   1.65127468e+01
#      1.21042948e+01   8.91430664e+00   6.41937828e+00   4.38838530e+00
#      2.80290461e+00   1.67022586e+00]
#   [  3.76389236e+01   2.12546997e+01   1.44032640e+01   1.11447563e+01
#      9.08273411e+00   7.30176449e+00   5.56310368e+00   3.93687725e+00
#      2.57214141e+00   1.55656564e+00]
#   [  9.72256470e+01   6.28776741e+01   3.97697487e+01   2.39383411e+01
#      1.36083164e+01   7.32909203e+00   3.76769066e+00   1.86393976e+00
#      8.94019186e-01   4.18292791e-01]
#   [  1.00002314e-17   4.50901651e+00   6.21083164e+00   6.62937117e+00
#      6.40730286e+00   5.80750370e+00   4.89378500e+00   3.70655394e+00
#      2.51311827e+00   1.54954100e+00]]
#
#  [[  6.30446243e+01   3.91413307e+01   2.67224255e+01   1.96661739e+01
#      1.53271646e+01   1.23687420e+01   9.97774982e+00   7.75704098e+00
#      5.62458277e+00   3.74420166e+00]
#   [  4.78623657e+01   2.81063328e+01   1.99850655e+01   1.62991085e+01
#      1.41010571e+01   1.21728048e+01   1.00785885e+01   7.81323862e+00
#      5.60001659e+00   3.69866705e+00]
#   [  8.83943863e+01   5.27430305e+01   3.11836414e+01   1.77776966e+01
#      9.68219566e+00   5.04315948e+00   2.52614784e+00   1.22481883e+00
#      5.78300714e-01   2.67238349e-01]
#   [ -7.28087022e-17   4.82478046e+00   6.78939342e+00   7.51071739e+00
#      7.69176769e+00   7.65265989e+00   7.28281307e+00   6.43796730e+00
#      5.08723402e+00   3.55300546e+00]]
#
#  [[  7.84168625e+01   4.85528831e+01   3.30806313e+01   2.43914890e+01
#      1.92358475e+01   1.59595003e+01   1.34557514e+01   1.10674534e+01
#      8.53538322e+00   6.04025555e+00]
#   [  6.06233444e+01   3.54584656e+01   2.52221718e+01   2.07459526e+01
#      1.82817707e+01   1.62487030e+01   1.40017452e+01   1.14004059e+01
#      8.63144112e+00   6.03079987e+00]
#   [  9.88344116e+01   5.75418587e+01   3.35467606e+01   1.89972229e+01
#      1.03201141e+01   5.37290812e+00   2.69243836e+00   1.30642223e+00
#      6.17325604e-01   2.85491019e-01]
#   [  5.87732869e-17   6.03538370e+00   8.55084610e+00   9.57772446e+00
#      1.00104599e+01   1.02545948e+01   1.01367540e+01   9.37902069e+00
#      7.80776215e+00   5.76551771e+00]]]

# %%
from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import gridspec
from matplotlib import rc, rcParams


# Make use of TeX
rc('text',usetex=True)

# Change all fonts to 'Computer Modern'
rc('font',**{'family':'serif','serif':['Computer Modern']})



# Define the labels for the plot
h=0.1
xlabel = r'radius R [kpc/h$_{%g}$]'%(h*100)
ylabel = r'ESD $\langle\Delta\Sigma\rangle$ [h$_{%g}$ M$_{\odot}$/pc$^2$]'%(h*100)

Nrows = 2
Ncolumns = 2

for i in xrange(len(envnames)):
    for e in xrange(len(esdnames)):
        plt.figure(1, figsize=(18, 13))
        Nsubplot = 100*Nrows+10*Ncolumns+i
        plt.subplot(Nsubplot)
        
        plt.plot(data_x, esds_av[i,e], label=plotlabels[e])
    
        (error_l[e])[(error_l[e])>=data_y[e]] = ((data_y[e][(error_l[e])>=data_y[e]])*0.9999999999)
    
        plt.errorbar(data_x, data_y[i], yerr=[error_l[i], error_h[i]], ls='', marker='o')
        plt.ylabel(r'%s'%ylabel,fontsize=15)
        plt.xlabel(r'%s'%xlabel,fontsize=15)
        
        
        plt.xscale('log')
        plt.yscale('log')
                
        plt.autoscale(enable=False, axis='both', tight=None)
        plt.axis([1e1,1e4,1e-1,1e4])
        plt.ylim(1e-1,1e4)
        
        plt.title(envnames[i], fontsize=15)
            
        plt.legend()


#plt.show()

plotname = '%s.png'%filename

plt.savefig(plotname, format='png')
print 'Written: ESD profile plot:', plotname

#plt.clf
# Out:
# Written: ESD profile plot: /disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output.png
