# %%
#!/usr/bin/python

import numpy as np
import pyfits
import os
import environment_utils as utils

from matplotlib import pyplot as plt
# %matplotlib inline

from matplotlib import pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import gridspec
from matplotlib import rc, rcParams

# Make use of TeX
rc('text',usetex=True)

# Change all fonts to 'Computer Modern'
rc('font',**{'family':'serif','serif':['Computer Modern']})



envnames = ['Void', 'Sheet', 'Filament', 'Knot']
esdnames = ['esd_total', 'esd_cen', 'esd_sat', 'esd_host']
plotlabels = ['ESD (av)', 'ESD (cen)', 'ESD (sat)', 'ESD (host)']
envcolors = ['red', 'green', 'blue', 'gold']
esdcolors = ['blue', 'green', 'red', 'purple']

esds = np.array([['%s%i'%(esd, env+1) for env in xrange(len(envnames))] for esd in esdnames])

print esds

#filename = '/disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output'
#filename = '/disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output_mstarweight'
filename = '/disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output_mstarweight_no-pointmass'
#filename = '/disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output_mstarweight_no-pointmass_angsepcor'

#filename = '/disks/shear10/brouwer_veersemeer/mcmc_output/shuffled-environment_mcmc_output_mstarweight_no-pointmass'


burn = 5000
# Out:
# [['esd_total1' 'esd_total2' 'esd_total3' 'esd_total4']
#  ['esd_cen1' 'esd_cen2' 'esd_cen3' 'esd_cen4']
#  ['esd_sat1' 'esd_sat2' 'esd_sat3' 'esd_sat4']
#  ['esd_host1' 'esd_host2' 'esd_host3' 'esd_host4']]

# %%
# Importing mcmc results
def import_mcmc(filename):

    mcmcname = '%s.fits'%filename
    headername = '%s.hdr'%filename
    
    print 'Importing MCMC results:', mcmcname
    print '                   and:', headername
    mcmccat = pyfits.open(mcmcname)[1]
    mcmcnames = mcmccat.columns.names
    mcmcdata = mcmccat.data
    
    mcmcmask = (mcmcdata['Mcen1'] != 0)
    end = np.sum(mcmcmask)
    
    mcmc = dict()
    for colname in mcmcnames:
        mcmc[colname] = (mcmcdata[colname])[burn:end]

    return mcmc, end, mcmcname, headername, mcmcmask

# %%
# Import header file
def read_header(headername):

    inputparams = dict()

    header = open(headername, 'r').read().split('\n')
    header = [header[i].split(' ') for i in xrange(len(header))]

    for line in header:
        if len(line)>1:
#            print line
            if line[0] == 'datafile':
                esdfiles = line[1].split(',')
            elif line[0] == 'covfile':
                covfile = line[1]
            elif 'fixed' in line:
                inputvalues = line[4].split(',')
                inputvalues = [float(inputvalues[p]) for p in xrange(len(inputvalues))]
                inputparams[line[0]] = inputvalues
    
    return esdfiles, covfile, inputparams

# %%
# Read ESD information
def read_esdfiles(esdfiles):
    
    data = np.loadtxt(esdfiles[0]).T
    data_x = data[0]

    data_y = np.zeros(len(data_x))
    error_h = np.zeros(len(data_x))
    error_l = np.zeros(len(data_x))
    
    print 'Imported ESD profiles: %i'%len(esdfiles)
    
    for f in xrange(len(esdfiles)):
        # Load the text file containing the stacked profile
        data = np.loadtxt(esdfiles[f]).T
    
        bias = data[4]
        bias[bias==-999] = 1
    
        datax = data[0]
        datay = data[1]/bias
        datay[datay==-999] = np.nan
    
        errorh = (data[3])/bias # covariance error
        errorl = (data[3])/bias # covariance error
        errorh[errorh==-999] = np.nan
        errorl[errorl==-999] = np.nan
        
        
        data_y = np.vstack([data_y, datay])
        error_h = np.vstack([error_h, errorh])
        error_l = np.vstack([error_l, errorl])
        
        print data[1]
        
    data_y = np.delete(data_y, 0, 0)
    error_h = np.delete(error_h, 0, 0)
    error_l = np.delete(error_l, 0, 0)
    
    return data_x, data_y, error_h, error_l

# %%
# Import MCMC results
mcmc, end, mcmcname, headername, mcmcmask = import_mcmc(filename)
print 'Samples: Created = %i, Burned = %i, Used = %i'%(end, burn, len(mcmc['Mcen1']))
print

# Import ESD profiles
esdfiles, covfile, inputparams = read_header(headername)
print 'Input parameters:', inputparams.keys()

data_x, data_y, error_h, error_l = read_esdfiles(esdfiles)
# Out:
# Importing MCMC results: /disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output_mstarweight_no-pointmass.fits
#                    and: /disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output_mstarweight_no-pointmass.hdr
# Samples: Created = 90500, Burned = 5000, Used = 85500
# Input parameters: ['zgal', 'Mstar', 'fc_sat', 'fsat']
# Imported ESD profiles: 4
# [ 46.77846868  51.372138    28.09369521  20.74563182  12.93081715
#    7.19693974   4.8558482    3.48258181   2.28865889   0.90138992]
# [ 34.05039797  45.47823071  18.39045489  10.47800327  16.88990791
#    6.9372894    5.23826005   4.31980542   3.10336016   1.52158704]
# [ 37.93151488  32.77394243  20.44101709  23.25279793  12.42728342
#    9.08070779   7.93464057   6.15817479   5.95139416   4.11273407]
# [ 32.64761848  74.55417164   7.99895158  25.61903758  10.33378152
#   -0.93481625   8.24799427   6.83822426   6.86023942   7.07227241]

# %%
# Taking the median result of all samples after the burn-in phase

def calc_esds_masses(inputparams, mcmc, esdnames, envnames):
        
    # Calculating the satellite fraction
    fsat = inputparams['fsat']
    
    esd_fracs = np.array([[1, 1-fsat[esd], fsat[esd], fsat[esd]] for esd in xrange(len(esdnames))])
    
    print 'ESD fractions:'
    print esd_fracs
    print
    
    #"""
    # Calculating the median ESD fits
    masslist = mcmc['Mavg1']
    index = len(masslist)/2
    sorts = np.argsort(masslist)
    esds_med = np.array((([[(mcmc[esds[e,i]][sorts])[index] for e in xrange(len(esdnames))] for i in xrange(len(envnames))])))
    #"""
    
    """
    # Selecting the result with the lowest chi2
    chi2list = mcmc['chi2']
    index = np.where(chi2list == np.amin(chi2list))[0][-1]
    esds_med = np.array([[(mcmc[esds[e,i]])[index] for e in xrange(len(esdnames))] for i in xrange(len(envnames))])
    """
    
    r=1
    print 'Median ESDs for radial bin %i:'%r
    tot = esds_med[0,:,r]
    print tot
    
    print 'Weighted ESDs for radial bin %i:'%r
    tot = esd_fracs[0]*esds_med[0,:,r]
    print tot
    
    print 'Total ESD:'
    print np.sum(tot[1:])
    
    
    massnames = ['Mcen', 'Msat', 'Mavg']
    masscolors = ['green', 'red', 'blue']
    masses = np.array([['%s%i'%(m, env+1) \
                        for env in xrange(len(envnames))] \
                        for m in massnames])
    print masses
    print
    masses_med = np.array([[(mcmc[masses[m, env]])[index] \
                           for env in xrange(len(envnames))] \
                           for m in xrange(len(massnames))])
    print masses_med

    return fsat, esd_fracs, masslist, esds_med

# %%
plt.figure(1, figsize=(10, 7))

for m in xrange(len(massnames)):
    plt.plot(np.arange(len(envnames)), masses_med[m], '--o', label=massnames[m], color = masscolors[m])

ylabel = r' Mass (M$_{\odot}$)'
xlabel = 'Environment'


#plt.xscale('log', fontsize=15)
plt.yscale('log', fontsize=15)

plt.tick_params(axis='both', which='major', labelsize=15)
plt.xticks(np.arange(len(envnames)), envnames)

plt.ylabel(r'%s'%ylabel, fontsize=15)
plt.xlabel(r'%s'%xlabel, fontsize=15)
plt.legend(fontsize=15)

plotname = '%s_masses.png'%filename

plt.savefig(plotname, format='png')
print 'Written: ESD profile plot:', plotname
# Out:
# [['Mcen1' 'Mcen2' 'Mcen3' 'Mcen4']
#  ['Msat1' 'Msat2' 'Msat3' 'Msat4']
#  ['Mavg1' 'Mavg2' 'Mavg3' 'Mavg4']]
#
# [[  2.70665436e+12   3.01021974e+12   7.53265436e+12   5.37406158e+12]
#  [  6.61769421e+11   1.56848816e+11   4.61255934e+11   8.11622072e+11]
#  [  2.34760936e+12   2.22319162e+12   4.78271504e+12   3.08922365e+12]]
# Written: ESD profile plot:
#  /disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output_mstarweight_no-pointmass_masses.png

# %%
nbins = 2e2

histmin = 1e10
histmax = 1e14
histbins = np.logspace(np.log10(histmin), np.log10(histmax), nbins)
histbins = np.append(histbins, histmax)
histcens = [(histbins[i]+histbins[i+1])/2 for i in xrange(len(histbins)-1)]

plt.figure(1, figsize=(15, 10), dpi=80)

xlabel = r' Mass (M$_{\odot}$)'

Nrows = len(massnames)
Ncolumns = 1

for m in xrange(len(massnames)):
    
    plt.figure(1, figsize=(18, 13))
    Nsubplot = 100*Nrows+10*Ncolumns+(m+1)
    plt.subplot(Nsubplot)

    for e in xrange(len(envnames)):
    
        obsname = masses[m, e]
        median = masses_med[m, e]
        obslist = (mcmc[obsname])
        
        hist, histbins = np.histogram(obslist, histbins)
        
        plt.plot(histcens, hist, color=envcolors[e], label=envnames[e])
        plt.axvline(x = masses_med[m, e], color=envcolors[e])

        plt.legend(fontsize=15)
        
        plt.xlabel(r'%s'%xlabel,fontsize=15)
        plt.ylabel(r'%s'%massnames[m],fontsize=15)
        plt.tick_params(axis='both', which='major', labelsize=14)
        
        plt.xscale('log')
        plt.yscale('log')

plotname = '%s_masshists.png'%filename

plt.savefig(plotname, format='png')
print 'Written: ESD profile plot:', plotname
# Out:
# Written: ESD profile plot: /disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output_mstarweight_no-pointmass_masshists.png

# %%
# A few tests

ESD_cen = np.median(mcmc['esd_cen1']*esd_fracs[0, 1], 0)
ESD_sat = np.median(mcmc['esd_sat1']*esd_fracs[0, 1], 0)
ESD_cen_plot = esds_med[0, 0]*esd_fracs[0, 1]


plt.plot(data_x, ESD_cen_plot)
plt.plot(data_x, ESD_cen)

plt.xscale('log')
plt.yscale('log')

# %%
# Define the labels for the plot
h=1
xlabel = r'radius R [kpc/h$_{%g}$]'%(h*100)
ylabel = r'ESD $\langle\Delta\Sigma\rangle$ [h$_{%g}$ M$_{\odot}$/pc$^2$]'%(h*100)

Nrows = 2
Ncolumns = 2

for env in xrange(len(envnames)):
    for esd in xrange(len(esdnames)):
        plt.figure(1, figsize=(18, 13))
        Nsubplot = 100*Nrows+10*Ncolumns+(env+1)
        plt.subplot(Nsubplot)
     
        plt.plot(data_x, esds_med[env, esd]*esd_fracs[env, esd], label=r'%s'%plotlabels[esd], color = esdcolors[esd])
        (error_l[esd])[(error_l[esd])>=data_y[esd]] = ((data_y[esd][(error_l[esd])>=data_y[esd]])*0.9999999999)
    
        plt.errorbar(data_x, data_y[env], yerr=[error_l[env], error_h[env]], ls='', marker='o', color = 'blue')
        plt.ylabel(r'%s'%ylabel,fontsize=15)
        plt.xlabel(r'%s'%xlabel,fontsize=15)
    
    # Plot total from ESD fractions
#    tot = esds_med[env, :]*np.array([esd_fracs[env, :]]*len(data_x)).T
#    plt.plot(data_x, np.sum(tot[1:], 0), label=r'Total from fractions')   

    plt.title(envnames[env], fontsize=20)

    
    plt.tick_params(axis='both', which='major', labelsize=16)
    plt.xscale('log', fontsize=15)
    plt.yscale('log', fontsize=15)
            
    plt.autoscale(enable=False, axis='both', tight=None)
    plt.axis([1e1,5e3,1e-1,1e3])
    plt.ylim(1e-1,1e3)
        
    plt.legend(fontsize=15)


#plt.show()

plotname = '%s.png'%filename

plt.savefig(plotname, format='png')
print 'Written: ESD profile plot:', plotname

#plt.clf
# Out:
# Written: ESD profile plot: /disks/shear10/brouwer_veersemeer/mcmc_output/environment_mcmc_output_mstarweight_no-pointmass.png

# %%
Mcen = 5e13
Msat = 5e10
R = data_x * 1e3

dSigma_cen = (Mcen/3e10)/(np.pi*data_x**0.5)
dSigma_sat = (Msat/2e7)/(np.pi*data_x**1.5)

print R

plt.plot(data_x, dSigma_cen)
plt.plot(data_x, dSigma_sat)
plt.plot(data_x, ESD_cen)
plt.plot(data_x, ESD_sat)
plt.errorbar(data_x, data_y[0], yerr=[error_l[0], error_h[0]], ls='', marker='o')

plt.xscale('log')
plt.yscale('log')
# Out:
# [   25848.9319246    40967.7962397    64929.5813704   102906.451503
#    163095.734448    258489.319246    409677.962397    649295.813704
#   1029064.51503    1630957.34448  ]

# %%
filenameshuff = '/disks/shear10/brouwer_veersemeer/mcmc_output/shuffled-environment_mcmc_output_mstarweight_no-pointmass'

# Import MCMC results
mcmcshuff, endshuff, mcmcnameshuff, headernameshuff, mcmcmaskshuff = import_mcmc(filenameshuff)
print 'Samples: Created = %i, Burned = %i, Used = %i'%(endshuff, burn, len(mcmcshuff['Mcen1']))
print

# Import ESD profiles
esdfileshuff, covfileshuff, inputparamshuff = read_header(headernameshuff)
print 'Input parameters:', inputparams.keys()
# Out:
# Importing MCMC results: /disks/shear10/brouwer_veersemeer/mcmc_output/shuffled-environment_mcmc_output_mstarweight_no-pointmass.fits
#                    and: /disks/shear10/brouwer_veersemeer/mcmc_output/shuffled-environment_mcmc_output_mstarweight_no-pointmass.hdr
# Samples: Created = 20000, Burned = 5000, Used = 15000
# Input parameters: ['zgal', 'Mstar', 'fc_sat', 'fsat']

# %%
masses_medshuff = np.array([[(mcmcshuff[masses[m, env]])[indexshuff] \
                       for env in xrange(len(envnames))] \
                       for m in xrange(len(massnames))])
